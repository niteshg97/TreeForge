# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# TreeForge - Exploratory Data Analysis"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import sys\n",
    "sys.path.append('..')\n",
    "\n",
    "from src.data.loader import load_and_process\n",
    "from src.eda.summary import (\n",
    "    get_summary_statistics,\n",
    "    get_class_distribution,\n",
    "    get_correlation_matrix,\n",
    ")\n",
    "from src.eda.visualization import (\n",
    "    plot_class_distribution,\n",
    "    plot_feature_distributions,\n",
    "    plot_correlation_heatmap,\n",
    ")\n",
    "\n",
    "df = load_and_process(persist=False)\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": ["get_summary_statistics(df)"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": ["get_class_distribution(df, 'class')"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": ["plot_class_distribution(df, 'class')"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "feature_cols = [c for c in df.columns if c != 'class']\n",
    "plot_feature_distributions(df, feature_cols)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "corr = get_correlation_matrix(df)\n",
    "plot_correlation_heatmap(corr)"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.10"}
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
